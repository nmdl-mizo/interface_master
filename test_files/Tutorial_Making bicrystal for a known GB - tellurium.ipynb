# %%
from interfacemaster.cellcalc import get_primitive_hkl, get_normal_from_MI, MID
from interfacemaster.interface_generator import core,\
print_near_axis, convert_vector_index, get_disorientation
from numpy import array, dot, round, var, average
from numpy.linalg import inv,norm

# %% [markdown]
# # Define an interface core class

# %% [markdown]
# Input two cif files.For GBs, input the same file; for interfaces, input two different files.
#
#
# The first structure is non-changed while the second one can be deformed to form an approximate CSL
#
# Please input files of CONVENTIONAL cells if you are not familiar with the indices in the primitive cell.

# %%
my_interface = core('cif_files/Te_mp-19_conventional_standard.cif',\
                    'cif_files/Te_mp-19_conventional_standard.cif')
# Out:
# Warning!, this programme will rewrite the POSCAR file in this dir!
# /Users/jasonxie/.local/lib/python3.8/site-packages/pymatgen/io/cif.py:1121: UserWarning: Issues encountered while parsing CIF: Some fractional co-ordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: %s" % "\n".join(self.warnings))

# %%
my_interface.atoms_2 = [1,1,1] - my_interface.atoms_2

# %%
#get the rotation mtx
R = get_disorientation(L1 = my_interface.conv_lattice_1, L2 = my_interface.conv_lattice_2, 
                       v1 = [1,-1,0], hkl1 = [1, 1, -2], \
                       v2 = [-1,-2,0], hkl2 = [-2, 1, -2], \
                       tol = 0.01)

# %%
my_interface.parse_limit(du = 1e-2, S  = 1e-2, sgm1=200, sgm2=200, dd = 1e-2)

#Do searching!
#We already know that there is a CSL by rotation 180 degrees
my_interface.search_fixed(R)
# Out:
# Congrates, we found an appx CSL!
#
# U1 =
# [[ 1  1  3]
#  [ 2  0 -1]
#  [ 0  1 -2]]; sigma_1 = 11
#
# U2 =
# [[-1 -1  4]
#  [ 1 -1  3]
#  [ 0  1  2]]; sigma_2 = 11
#
# D =
# [[ 0.99853888 -0.         -0.00110625]
#  [-0.          1.         -0.        ]
#  [ 0.00192983 -0.          1.00146112]]

# %% [markdown]
# 'U1', 'U2' are two sets of indices of the CSL in the two crystals' frames,
# 'D' is the deformation applied to the crystal 2 to form an approximate CSL
#
# As you can see, to form a twinning structure we need to deform the structure provided!

# %% [markdown]
# # Convert the miller indices to be expressed in the primitive cell

# %% [markdown]
# Now we need to specify the orientation of our interface, which is by giving a miller indices in expressed in the primitive cell.

# %%
"""
The interface plane is the [1,-1,2] plane in the conventional cell and now we \
transform it into primitive cell
"""
hkl = get_primitive_hkl(array([1, 1, -2]), my_interface.conv_lattice_1, my_interface.lattice_1)
hkl
# Out:
# array([-2,  1,  2])

# %% [markdown]
# # Compute the indices of the two slabs to make bicrystal

# %% [markdown]
# Now let's compute the indices of the two slabs forming the interface
# If you want a near orthogonal bicrystal, please set 'orthogonal to yes,
# and adjust the lim & tol.

# %%
my_interface.compute_bicrystal(hkl, normal_ortho= True, lim = 50, tol = 1e-3)
# Out:
# cell 1:
# [[ 7  1  1]
#  [ 0  2  0]
#  [-4  0  1]]
# cell 2:
# [[ 7  1  1]
#  [ 0  2  0]
#  [-4  0  1]]

# %% [markdown]
# Here we obtained the two sets of indices to build a bicrystal

# %% [markdown]
# # Make a bicrystal!

# %% [markdown]
# You can adjust the bicrystal by
# 1. do expansion by set 'xyz' = [dimX, dimY, dimZ]
# 2. do RBT by 'dzdy' = a translation vector
# (please confine dzdy in the interface plane,
# for RBT in the normal, please use 'dp1' and 'dp2', to make vacuum in the interface use 'dx');
# 3. introduce vacuum in the interface by 'dx' = the distance spacing the two crystals
# 4. adjust the termination by 'dp1', 'dp2' = length of shift of the position of
# the termination from the interface into the bulk
# 5. introduce vacuum to make a surface in the end of the bicrystal by
# 'vx' = length of the vaccumn
#
# default: xyz = [1,1,1] and others = 0

# %%
my_interface.bicrystal_structure
# Out:
# Structure Summary
# Lattice
#     abc : 79.1464707956195 7.815661758214144 7.475420991253361
#  angles : 90.0 89.91302280165155 90.00000000000001
#  volume : 4624.155876663169
#       A : 79.1464707956195 -6.1e-15 -3.6e-15
#       B : -9e-16 7.815661758214144 -2e-16
#       C : 0.0113479724003891 -4e-16 7.475412377922289
# PeriodicSite: Te (34.8945, 2.8568, 1.4467) [0.4409, 0.3655, 0.1935]
# PeriodicSite: Te (33.0936, 6.7647, 0.0875) [0.4181, 0.8655, 0.0117]
# PeriodicSite: Te (38.4962, 2.8568, 4.1650) [0.4863, 0.3655, 0.5572]
# PeriodicSite: Te (36.6953, 6.7647, 2.8058) [0.4636, 0.8655, 0.3753]
# PeriodicSite: Te (24.1008, 2.8568, 0.7671) [0.3045, 0.3655, 0.1026]
# PeriodicSite: Te (27.7024, 2.8568, 3.4854) [0.3499, 0.3655, 0.4663]
# PeriodicSite: Te (25.9016, 6.7647, 2.1263) [0.3272, 0.8655, 0.2844]
# PeriodicSite: Te (31.3041, 2.8568, 6.2038) [0.3954, 0.3655, 0.8299]
# PeriodicSite: Te (29.5033, 6.7647, 4.8446) [0.3727, 0.8655, 0.6481]
# PeriodicSite: Te (13.3070, 2.8568, 0.0875) [0.1681, 0.3655, 0.0117]
# PeriodicSite: Te (16.9087, 2.8568, 2.8058) [0.2136, 0.3655, 0.3753]
# PeriodicSite: Te (15.1079, 6.7647, 1.4467) [0.1909, 0.8655, 0.1935]
# PeriodicSite: Te (20.5104, 2.8568, 5.5242) [0.2590, 0.3655, 0.7390]
# PeriodicSite: Te (18.7096, 6.7647, 4.1650) [0.2363, 0.8655, 0.5572]
# PeriodicSite: Te (22.3113, 6.7647, 6.8833) [0.2818, 0.8655, 0.9208]
# PeriodicSite: Te (6.1150, 2.8568, 2.1263) [0.0772, 0.3655, 0.2844]
# PeriodicSite: Te (4.3141, 6.7647, 0.7671) [0.0545, 0.8655, 0.1026]
# PeriodicSite: Te (9.7167, 2.8568, 4.8446) [0.1227, 0.3655, 0.6481]
# PeriodicSite: Te (7.9158, 6.7647, 3.4854) [0.0999, 0.8655, 0.4663]
# PeriodicSite: Te (11.5175, 6.7647, 6.2038) [0.1454, 0.8655, 0.8299]
# PeriodicSite: Te (2.5246, 2.8568, 6.8833) [0.0318, 0.3655, 0.9208]
# PeriodicSite: Te (0.7238, 6.7647, 5.5242) [0.0090, 0.8655, 0.7390]
# PeriodicSite: Te (37.8921, 1.0510, 1.2201) [0.4787, 0.1345, 0.1632]
# PeriodicSite: Te (27.0984, 1.0510, 0.5406) [0.3424, 0.1345, 0.0723]
# PeriodicSite: Te (30.7001, 1.0510, 3.2589) [0.3878, 0.1345, 0.4359]
# PeriodicSite: Te (28.8992, 4.9588, 1.8997) [0.3651, 0.6345, 0.2541]
# PeriodicSite: Te (34.3018, 1.0510, 5.9772) [0.4333, 0.1345, 0.7996]
# PeriodicSite: Te (32.5009, 4.9588, 4.6181) [0.4106, 0.6345, 0.6178]
# PeriodicSite: Te (36.1026, 4.9588, 7.3364) [0.4560, 0.6345, 0.9814]
# PeriodicSite: Te (19.9063, 1.0510, 2.5793) [0.2515, 0.1345, 0.3450]
# PeriodicSite: Te (18.1055, 4.9588, 1.2201) [0.2287, 0.6345, 0.1632]
# PeriodicSite: Te (23.5080, 1.0510, 5.2976) [0.2969, 0.1345, 0.7087]
# PeriodicSite: Te (21.7072, 4.9588, 3.9385) [0.2742, 0.6345, 0.5269]
# PeriodicSite: Te (25.3089, 4.9588, 6.6568) [0.3196, 0.6345, 0.8905]
# PeriodicSite: Te (9.1126, 1.0510, 1.8997) [0.1151, 0.1345, 0.2541]
# PeriodicSite: Te (7.3118, 4.9588, 0.5406) [0.0924, 0.6345, 0.0723]
# PeriodicSite: Te (12.7143, 1.0510, 4.6181) [0.1606, 0.1345, 0.6178]
# PeriodicSite: Te (10.9135, 4.9588, 3.2589) [0.1378, 0.6345, 0.4359]
# PeriodicSite: Te (16.3160, 1.0510, 7.3364) [0.2060, 0.1345, 0.9814]
# PeriodicSite: Te (14.5152, 4.9588, 5.9772) [0.1833, 0.6345, 0.7996]
# PeriodicSite: Te (1.9206, 1.0510, 3.9385) [0.0242, 0.1345, 0.5269]
# PeriodicSite: Te (0.1197, 4.9588, 2.5793) [0.0015, 0.6345, 0.3450]
# PeriodicSite: Te (5.5223, 1.0510, 6.6568) [0.0696, 0.1345, 0.8905]
# PeriodicSite: Te (3.7214, 4.9588, 5.2976) [0.0469, 0.6345, 0.7087]
# PeriodicSite: Te (29.7482, -0.0000, 0.0515) [0.3759, 0.0000, 0.0069]
# PeriodicSite: Te (33.3499, -0.0000, 2.7698) [0.4213, 0.0000, 0.3705]
# PeriodicSite: Te (31.5490, 3.9078, 1.4107) [0.3986, 0.5000, 0.1887]
# PeriodicSite: Te (36.9516, -0.0000, 5.4882) [0.4668, 0.0000, 0.7342]
# PeriodicSite: Te (35.1507, 3.9078, 4.1290) [0.4440, 0.5000, 0.5523]
# PeriodicSite: Te (38.7524, 3.9078, 6.8473) [0.4895, 0.5000, 0.9160]
# PeriodicSite: Te (22.5561, -0.0000, 2.0903) [0.2850, 0.0000, 0.2796]
# PeriodicSite: Te (20.7553, 3.9078, 0.7311) [0.2622, 0.5000, 0.0978]
# PeriodicSite: Te (26.1578, -0.0000, 4.8086) [0.3304, 0.0000, 0.6433]
# PeriodicSite: Te (24.3570, 3.9078, 3.4494) [0.3077, 0.5000, 0.4614]
# PeriodicSite: Te (27.9587, 3.9078, 6.1678) [0.3531, 0.5000, 0.8251]
# PeriodicSite: Te (11.7624, -0.0000, 1.4107) [0.1486, 0.0000, 0.1887]
# PeriodicSite: Te (9.9616, 3.9078, 0.0515) [0.1259, 0.5000, 0.0069]
# PeriodicSite: Te (15.3641, -0.0000, 4.1290) [0.1940, 0.0000, 0.5523]
# PeriodicSite: Te (13.5633, 3.9078, 2.7698) [0.1713, 0.5000, 0.3705]
# PeriodicSite: Te (18.9658, -0.0000, 6.8473) [0.2395, 0.0000, 0.9160]
# PeriodicSite: Te (17.1649, 3.9078, 5.4882) [0.2168, 0.5000, 0.7342]
# PeriodicSite: Te (0.9687, -0.0000, 0.7311) [0.0122, 0.0000, 0.0978]
# PeriodicSite: Te (4.5704, -0.0000, 3.4494) [0.0577, 0.0000, 0.4614]
# PeriodicSite: Te (2.7695, 3.9078, 2.0903) [0.0350, 0.5000, 0.2796]
# PeriodicSite: Te (8.1721, -0.0000, 6.1678) [0.1031, 0.0000, 0.8251]
# PeriodicSite: Te (6.3712, 3.9078, 4.8086) [0.0804, 0.5000, 0.6433]
# PeriodicSite: Te (39.9446, 3.9078, 2.2138) [0.5046, 0.5000, 0.2961]
# PeriodicSite: Te (41.7413, -0.0000, 0.8546) [0.5274, 0.0000, 0.1143]
# PeriodicSite: Te (43.5494, 3.9078, 6.9708) [0.5501, 0.5000, 0.9325]
# PeriodicSite: Te (45.3461, -0.0000, 5.6117) [0.5728, 0.0000, 0.7507]
# PeriodicSite: Te (47.1428, 3.9078, 4.2525) [0.5956, 0.5000, 0.5689]
# PeriodicSite: Te (48.9395, -0.0000, 2.8933) [0.6183, 0.0000, 0.3870]
# PeriodicSite: Te (50.7362, 3.9078, 1.5342) [0.6410, 0.5000, 0.2052]
# PeriodicSite: Te (52.5330, -0.0000, 0.1750) [0.6637, 0.0000, 0.0234]
# PeriodicSite: Te (54.3410, 3.9078, 6.2913) [0.6865, 0.5000, 0.8416]
# PeriodicSite: Te (56.1377, -0.0000, 4.9321) [0.7092, 0.0000, 0.6598]
# PeriodicSite: Te (57.9345, 3.9078, 3.5729) [0.7319, 0.5000, 0.4780]
# PeriodicSite: Te (59.7312, -0.0000, 2.2138) [0.7546, 0.0000, 0.2961]
# PeriodicSite: Te (61.5279, 3.9078, 0.8546) [0.7774, 0.5000, 0.1143]
# PeriodicSite: Te (63.3360, -0.0000, 6.9708) [0.8001, 0.0000, 0.9325]
# PeriodicSite: Te (65.1327, 3.9078, 5.6117) [0.8228, 0.5000, 0.7507]
# PeriodicSite: Te (66.9294, -0.0000, 4.2525) [0.8456, 0.0000, 0.5689]
# PeriodicSite: Te (68.7261, 3.9078, 2.8933) [0.8683, 0.5000, 0.3870]
# PeriodicSite: Te (70.5229, -0.0000, 1.5342) [0.8910, 0.0000, 0.2052]
# PeriodicSite: Te (72.3196, 3.9078, 0.1750) [0.9137, 0.5000, 0.0234]
# PeriodicSite: Te (74.1276, -0.0000, 6.2913) [0.9365, 0.0000, 0.8416]
# PeriodicSite: Te (75.9244, 3.9078, 4.9321) [0.9592, 0.5000, 0.6598]
# PeriodicSite: Te (77.7211, -0.0000, 3.5729) [0.9819, 0.0000, 0.4780]
# PeriodicSite: Te (39.6965, 2.8568, 4.8961) [0.5015, 0.3655, 0.6550]
# PeriodicSite: Te (41.4932, 6.7647, 3.5369) [0.5242, 0.8655, 0.4731]
# PeriodicSite: Te (43.2899, 2.8568, 2.1778) [0.5469, 0.3655, 0.2913]
# PeriodicSite: Te (45.0866, 6.7647, 0.8186) [0.5696, 0.8655, 0.1095]
# PeriodicSite: Te (46.8947, 2.8568, 6.9348) [0.5924, 0.3655, 0.9277]
# PeriodicSite: Te (48.6914, 6.7647, 5.5757) [0.6151, 0.8655, 0.7459]
# PeriodicSite: Te (50.4881, 2.8568, 4.2165) [0.6378, 0.3655, 0.5641]
# PeriodicSite: Te (52.2849, 6.7647, 2.8574) [0.6606, 0.8655, 0.3822]
# PeriodicSite: Te (54.0816, 2.8568, 1.4982) [0.6833, 0.3655, 0.2004]
# PeriodicSite: Te (55.8783, 6.7647, 0.1390) [0.7060, 0.8655, 0.0186]
# PeriodicSite: Te (57.6864, 2.8568, 6.2553) [0.7287, 0.3655, 0.8368]
# PeriodicSite: Te (59.4831, 6.7647, 4.8961) [0.7515, 0.8655, 0.6550]
# PeriodicSite: Te (61.2798, 2.8568, 3.5369) [0.7742, 0.3655, 0.4731]
# PeriodicSite: Te (63.0765, 6.7647, 2.1778) [0.7969, 0.8655, 0.2913]
# PeriodicSite: Te (64.8733, 2.8568, 0.8186) [0.8196, 0.3655, 0.1095]
# PeriodicSite: Te (66.6813, 6.7647, 6.9348) [0.8424, 0.8655, 0.9277]
# PeriodicSite: Te (68.4780, 2.8568, 5.5757) [0.8651, 0.3655, 0.7459]
# PeriodicSite: Te (70.2748, 6.7647, 4.2165) [0.8878, 0.8655, 0.5641]
# PeriodicSite: Te (72.0715, 2.8568, 2.8574) [0.9106, 0.3655, 0.3822]
# PeriodicSite: Te (73.8682, 6.7647, 1.4982) [0.9333, 0.8655, 0.2004]
# PeriodicSite: Te (75.6649, 2.8568, 0.1390) [0.9560, 0.3655, 0.0186]
# PeriodicSite: Te (77.4730, 6.7647, 6.2553) [0.9787, 0.8655, 0.8368]
# PeriodicSite: Te (40.8981, 4.9588, 6.4818) [0.5166, 0.6345, 0.8671]
# PeriodicSite: Te (42.6948, 1.0510, 5.1226) [0.5393, 0.1345, 0.6853]
# PeriodicSite: Te (44.4915, 4.9588, 3.7635) [0.5621, 0.6345, 0.5034]
# PeriodicSite: Te (46.2882, 1.0510, 2.4043) [0.5848, 0.1345, 0.3216]
# PeriodicSite: Te (48.0850, 4.9588, 1.0451) [0.6075, 0.6345, 0.1398]
# PeriodicSite: Te (49.8930, 1.0510, 7.1614) [0.6303, 0.1345, 0.9580]
# PeriodicSite: Te (51.6897, 4.9588, 5.8022) [0.6530, 0.6345, 0.7762]
# PeriodicSite: Te (53.4865, 1.0510, 4.4430) [0.6757, 0.1345, 0.5944]
# PeriodicSite: Te (55.2832, 4.9588, 3.0839) [0.6984, 0.6345, 0.4125]
# PeriodicSite: Te (57.0799, 1.0510, 1.7247) [0.7212, 0.1345, 0.2307]
# PeriodicSite: Te (58.8766, 4.9588, 0.3655) [0.7439, 0.6345, 0.0489]
# PeriodicSite: Te (60.6847, 1.0510, 6.4818) [0.7666, 0.1345, 0.8671]
# PeriodicSite: Te (62.4814, 4.9588, 5.1226) [0.7893, 0.6345, 0.6853]
# PeriodicSite: Te (64.2781, 1.0510, 3.7635) [0.8121, 0.1345, 0.5034]
# PeriodicSite: Te (66.0749, 4.9588, 2.4043) [0.8348, 0.6345, 0.3216]
# PeriodicSite: Te (67.8716, 1.0510, 1.0451) [0.8575, 0.1345, 0.1398]
# PeriodicSite: Te (69.6796, 4.9588, 7.1614) [0.8803, 0.6345, 0.9580]
# PeriodicSite: Te (71.4764, 1.0510, 5.8022) [0.9030, 0.1345, 0.7762]
# PeriodicSite: Te (73.2731, 4.9588, 4.4430) [0.9257, 0.6345, 0.5944]
# PeriodicSite: Te (75.0698, 1.0510, 3.0839) [0.9484, 0.1345, 0.4125]
# PeriodicSite: Te (76.8665, 4.9588, 1.7247) [0.9712, 0.6345, 0.2307]
# PeriodicSite: Te (78.6632, 1.0510, 0.3655) [0.9939, 0.1345, 0.0489]

# %%
my_interface.get_bicrystal(xyz_1 = [1,1,1], xyz_2 = [1,1,1], dx = 0)
# Out:
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]

# %% [markdown]
# Good! You have made a 'POSCAR' file of this bicrystal, we also generated two files named 'cell_1.cif' and 'cell_2.cif' providing the structure of the two slabs.

# %%
norm(my_interface.CNID[:,0])
# Out:
# 7.475420991253359

# %%
norm(my_interface.CNID[:,1])
# Out:
# 7.815661758214145

# %%
#To sample the CNID, try
my_interface.sample_CNID(grid = [8,8], xyz_1 = [1,1,1], xyz_2 = [1,1,1], dx = 0.5)
# Out:
# CNID
# [[ 1. -1.]
#  [ 0. -2.]
#  [ 1.  0.]]
# making 64 files...
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# [[ 3.95732354e+01 -9.40209879e-16  1.13479724e-02]
#  [-3.03699467e-15  7.81566176e+00 -4.33856382e-16]
#  [-1.80398287e-15 -1.69469465e-16  7.47541238e+00]]
# completed

# %% [markdown]
# Please check the generated 'POSCAR.x.y' files.
# The CNID here is expressed in the primitive cell's frame.
# You can refer to the cartesian coordinates or in the conventional cell's frame

# %%
CNID_cartesian = round(my_interface.CNID,8)
CNID_cartesian
# Out:
# array([[-2.25618721,  6.76856163],
#        [-3.90783088, -3.90783088],
#        [-5.959899  , -0.        ]])

# %%
CNID_conv = round(dot(inv(my_interface.conv_lattice_1)\
                              , my_interface.CNID),8)
CNID_conv
# Out:
# array([[-1.,  1.],
#        [-1., -1.],
#        [-1., -0.]])
